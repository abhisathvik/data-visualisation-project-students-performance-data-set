# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Documents/DV data sets/studentsperformance.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['gender'].value_counts(normalize=True)
data['gender'].value_counts(dropna=True).plot.barh(color='blue')
plt.title(' Number of male and female students')
plt.xlabel('Count')
plt.ylabel('Gender')
plt.show()

# %%
df = data.groupby('gender').size()
df.plot(kind='pie',subplots=True,autopct='%0.f%%')
plt.title('pie chart of gender')
plt.show()

# %%
x = data['gender'].value_counts(normalize=True)
y = data['gender'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of gender vs count')
plt.xlabel('male and female')
plt.show()

# %%
 data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['race/ethnicity'].value_counts(normalize=True)
data['race/ethnicity'].value_counts(dropna=False).plot.bar(color=['red','green','blue','yellow','violet'])
plt.title('Comparison of race/ethnicity/gropus')
plt.xlabel('race/ethnicity/group')
plt.ylabel('count')
plt.show()

# %%
data['race/ethnicity'].value_counts(normalize=True)
data['race/ethnicity'].value_counts(dropna=False).plot.barh(color=['red','green','blue','yellow','violet'])
plt.title('Comparison of race/ethnicity/gropus')
plt.ylabel('race/ethnicity/group')
plt.xlabel('count')
plt.show()

# %%
df = data.groupby('race/ethnicity').size()
df.plot(kind='pie',subplots=True,autopct='%0.f%%')
plt.title('pie chart of race/ethnicity/groups')
plt.show()

# %%
x=data['race/ethnicity'].value_counts(normalize=True)
y=data['race/ethnicity'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of race/ethincity/groups vs count')
plt.xlabel('group A, group e, group b, group d, group c')
plt.show()

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['parental level of education'].value_counts(normalize=True)
data['parental level of education'].value_counts(dropna=False).plot.bar(color=['red','green','blue','yellow','violet','black'])
plt.title('Comparison of parental level of education')
plt.xlabel('parental level of education')
plt.ylabel('count')
plt.show()

# %%
data['parental level of education'].value_counts(normalize=True)
data['parental level of education'].value_counts(dropna=False).plot.barh(color=['red','green','blue','yellow','violet','black'])
plt.title('Comparison of parental level of education')
plt.ylabel('parental level of education')
plt.xlabel('count')
plt.show()

# %%
df = data.groupby('parental level of education').size()
df.plot(kind='pie',subplots=True,autopct='%0.f%%')
plt.title('pie chart of parental level of education')
plt.show()

# %%
x=data['parental level of education'].value_counts(normalize=True)
y=data['parental level of education'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of parental level of education vs count')
plt.xlabel('masters degree,bachelors degree,some high school,\nhigh school,associates degree,some college')
plt.show()

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['lunch'].value_counts(normalize=True)
data['lunch'].value_counts(dropna=False).plot.barh(color=['red','green'])
plt.title('Comparison of lunch')
plt.ylabel('type of lunch')
plt.xlabel('count')
plt.show()

# %%
data['lunch'].value_counts(normalize=True)
data['lunch'].value_counts(dropna=False).plot.bar(color=['red','green'])
plt.title('Comparison of lunch')
plt.xlabel('type of lunch')
plt.ylabel('count')
plt.show()

# %%
df = data.groupby('lunch').size()
df.plot(kind='pie',subplots=True,autopct='%0.f%%')
plt.title('pie chart of type of lunch')
plt.show()

# %%
x=data['lunch'].value_counts(normalize=True)
y=data['lunch'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of type of lunch vs count')
plt.xlabel('free/reduced and standard')
plt.show()

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
data['test preparation course'].value_counts(normalize=True)
data['test preparation course'].value_counts(dropna=False).plot.barh(color=['red','green'])
plt.title('Comparison of completion of test preparation')
plt.ylabel('completion of test preparation')
plt.xlabel('count')
plt.show()

# %%
data['test preparation course'].value_counts(normalize=True)
data['test preparation course'].value_counts(dropna=False).plot.bar(color=['red','green'])
plt.title('Comparison of completion of test preparation')
plt.xlabel('completion of test preparation')
plt.ylabel('count')
plt.show()

# %%
df = data.groupby('test preparation course').size()
df.plot(kind='pie',subplots=True,autopct='%0.1f%%')
plt.title('pie chart of completion of test preparation')
plt.show()

# %%
x=data['test preparation course'].value_counts(normalize=True)
y=data['test preparation course'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of test preparation course vs count')
plt.xlabel('completed and none')
plt.show()

# %%
data['math score'].value_counts()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: math score, Length: 81, dtype: int64

# %%
data['math score'].value_counts(normalize=True)
data['math score'].value_counts(dropna=False).plot.bar(figsize=(15,10),color='red')
plt.title('Comparison of math scores')
plt.xlabel('marks')
plt.ylabel('count')
plt.show()

# %%
x=data['math score'].value_counts(normalize=True)
y=data['math score'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of math score vs count')
plt.xlabel('math score')
plt.ylabel('count')
plt.show()

# %%
data['reading score'].value_counts()
# Out:
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: reading score, Length: 72, dtype: int64

# %%
data['reading score'].value_counts(normalize=True)
data['reading score'].value_counts(dropna=False).plot.bar(figsize=(15,10),color='cyan')
plt.title('Comparison of reading score')
plt.xlabel('marks')
plt.ylabel('count')
plt.show()

# %%
x=data['reading score'].value_counts(normalize=True)
y=data['reading score'].value_counts(dropna=False)
plt.scatter(x,y)
plt.title('Scatter plot of reading score vs count')
plt.xlabel('reading score')
plt.ylabel('count')
plt.show()

# %%
data['writing score'].value_counts()
# Out:
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 28     1
# 35     1
# 19     1
# 22     1
# 23     1
# Name: writing score, Length: 77, dtype: int64

# %%
data['writing score'].value_counts(normalize=True)
data['writing score'].value_counts(dropna=False).plot.bar(figsize=(15,10),color='green')
plt.title('Comparison of writing score')
plt.xlabel('marks')
plt.ylabel('count')
plt.show()

# %%
x = data['writing score'].value_counts(normalize=True)
y = data['writing score'].value_counts(dropna=False)
plt.scatter(x,y)
plt.xlabel('writing score')
plt.ylabel('count')
plt.show()

# %%
x=data['math score'].value_counts(normalize=True)
y=data['math score'].value_counts(dropna=False)
a=data['reading score'].value_counts(normalize=True)
b=data['reading score'].value_counts(dropna=False)
c=data['writing score'].value_counts(normalize=True)
d=data['writing score'].value_counts(dropna=False)
plt.scatter(x,y,marker='1',s=200)
plt.scatter(a,b,marker=2,s=150)
plt.scatter(c,d,s=50)
plt.title('Scatter plot of scores vs count')
plt.xlabel('scores in maths, reading, writing')
plt.ylabel('count')
plt.legend(['math score','reading score','writing score'])
plt.show()

# %%
sns.histplot(data['math score'],kde=True)
plt.show()

# %%
sns.histplot(data['reading score'],kde=True)
plt.show()

# %%
sns.histplot(data['writing score'],kde=True)
plt.show()

# %%
sns.histplot(data['math score'],kde=True)
sns.histplot(data['reading score'],kde=True)
sns.histplot(data['writing score'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
sns.histplot(data['math score'],kde=True)
plt.subplot(1,3,2)
sns.histplot(data['reading score'],kde=True)
plt.subplot(1,3,3)
sns.histplot(data['writing score'],kde=True)
plt.show()

# %%
plt.subplots(figsize=(12,5))
sns.countplot(x='parental level of education', data=data, hue='test preparation course')
plt.show()

# %%
plt.subplots(figsize=(12,5))
sns.countplot(x='race/ethnicity', data=data, hue='test preparation course')
plt.show()

# %%
plt.figure(figsize=(5,5))
passmarks=36
data['math_pass']= np.where(data['math score']<passmarks,'Fail','Pass')
data['math_pass'].value_counts(dropna=False).plot.bar()
plt.xlabel('pass or fail')
plt.ylabel('count')
plt.title('comparision of students who wrote the math test')
plt.show()

# %%
plt.figure(figsize=(5,5))
passmarks=36
data['reading_pass']= np.where(data['reading score']<passmarks,'Fail','Pass')
data['reading_pass'].value_counts(dropna=False).plot.bar()
plt.xlabel('pass or fail')
plt.ylabel('count')
plt.title('comparision of students who attended the reading test')
plt.show()

# %%
plt.figure(figsize=(5,5))
passmarks=36
data['writing_pass']= np.where(data['writing score']<passmarks,'Fail','Pass')
data['writing_pass'].value_counts(dropna=False).plot.bar()
plt.xlabel('pass or fail')
plt.ylabel('count')
plt.title('comparision of students who attended the writing test')
plt.show()

# %%
data['total_score']= data['math score']+data['reading score']+data['writing score']
data['total_score'].value_counts(normalize=True)
data['total_score'].value_counts(dropna=True).plot.bar(figsize=(50,10))
plt.show()

# %%
from math import *
data['percentage']= data['total_score']/3
for i in range(0,1000):
    data['percentage'][i]=ceil(data['percentage'][i])
data['percentage'].value_counts(normalize=True)
data['percentage'].value_counts(dropna=False).plot.bar(figsize=(15,10))
plt.xlabel('percentage')
plt.ylabel('count')
plt.title('comparision of overall perecentages obtained by students')
plt.show()
# Out:
# /var/folders/lg/l5kr68x905x9_d6hr5bk8f380000gn/T/ipykernel_43256/3018048442.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['percentage'][i]=ceil(data['percentage'][i])

# %%
data['status'] = data.apply(lambda x : 'Fail' if x['math_pass']  == 'Fail' or 
                            x['reading_pass'] == 'Fail' or x['writing_pass'] == 'Fail'
                            else 'pass', axis = 1)
data['status'].value_counts(dropna=False).plot.bar()
plt.title('overall results')
plt.xlabel('status')
plt.ylabel('count')
plt.show()
